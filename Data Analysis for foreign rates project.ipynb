# %% [markdown]
# # Welcome to Part 2

# %% [markdown]
# ## 1. Libraries used
# ### I downloaded all libraries used for this project.

# %%
#install the connector library
# %pip install mysql-connector-python

#import the connector
import mysql.connector

#create the connection object and cursor object
from mysql.connector import Error

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Connecting to database
#
#
# ### I connected to my database "MYSQL"

# %%
connection = mysql.connector.connect(host='***********',
                                         database='***********',
                                         user='***********',
                                     password='***********')
if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

else: 
    print("Error while connecting to MySQL", e)
# Out:
# Connected to MySQL Server version  5.5.5-10.4.25-MariaDB
# You're connected to database:  ('mydbuser',)

# %% [markdown]
# ## 3. Converting database to a dataframe
#
#
# ### I converted my database to a dataframe before I performede analysis on it.

# %%
#df = pd.read_sql('SELECT * FROM forextrade ORDER BY DATE DESC LIMIT 20', con = connection)
df = pd.read_sql('SELECT * FROM forextrade', con = connection)
df
# Out:
#                   DATE  AUD_CAD_BUY  AUD_CAD_SELL  AUD_CHF_BUY  AUD_CHF_SELL  \
# 0  2023-01-13 02:54:47      0.93126       0.93153      0.64639       0.64656
# 1  2023-01-13 02:55:09      0.93133       0.93162      0.64644       0.64660
# 2  2023-01-13 02:55:30      0.93133       0.93160      0.64643       0.64659
# 3  2023-01-13 02:55:51      0.93123       0.93151      0.64635       0.64652
# 4  2023-01-13 02:56:11      0.93118       0.93147      0.64630       0.64649
# 5  2023-01-13 02:56:30      0.93121       0.93151      0.64636       0.64657
# 6  2023-01-13 02:56:50      0.93121       0.93151      0.64636       0.64654
# 7  2023-01-13 02:57:10      0.93116       0.93146      0.64636       0.64655
# 8  2023-01-13 02:57:30      0.93116       0.93144      0.64630       0.64647
# 9  2023-01-13 02:57:51      0.93108       0.93135      0.64622       0.64637
# 10 2023-01-13 02:58:11      0.93111       0.93140      0.64624       0.64641
# ...

# %% [markdown]
# # 4. Data analsysis
#
# ### I wanted to know the basic infomation of my dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Columns: 137 entries, DATE to ZAR_JPY_SELL
# dtypes: datetime64[ns](1), float64(136)
# memory usage: 41.9 KB

# %%
df.describe()
# Out:
#        AUD_CAD_BUY  AUD_CAD_SELL  AUD_CHF_BUY  AUD_CHF_SELL  AUD_HKD_BUY  \
# count    39.000000     39.000000    39.000000     39.000000    39.000000
# mean      0.930863      0.931141     0.646013      0.646188     5.433552
# std       0.000269      0.000275     0.000262      0.000262     0.002195
# min       0.930400      0.930670     0.645630      0.645790     5.430510
# 25%       0.930670      0.930950     0.645785      0.645965     5.431815
# 50%       0.930770      0.931060     0.645900      0.646080     5.432640
# 75%       0.931120      0.931405     0.646230      0.646400     5.435175
# max       0.931330      0.931620     0.646440      0.646600     5.437510
#
#        AUD_HKD_SELL  AUD_JPY_BUY  AUD_JPY_SELL  AUD_NZD_BUY  AUD_NZD_SELL  \
# count     39.000000    39.000000     39.000000    39.000000     39.000000
# mean       5.434227    89.814513     89.842308     1.090118      1.090496
# std        0.002228     0.053397      0.053624     0.000239      0.000238
# ...

# %% [markdown]
# # Data Visualization
#
#
# ### I created a few line charts for some of the popular currency pairs.

# %%
# Draw a line chart
ax = plt.gca()


df.plot(x="DATE", y="AUD_CAD_BUY", ax=ax)
df.plot(x="DATE", y="AUD_CAD_SELL", ax=ax)
#plt.ylim(0, 1)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Draw a line chart
ax = plt.gca()


df.plot(x="DATE", y="USD_CAD_BUY", ax=ax)
df.plot(x="DATE", y="USD_CAD_SELL", ax=ax)
#plt.ylim(0, 1)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Draw a line chart
ax = plt.gca()


df.plot(x="DATE", y="AUD_CHF_BUY", ax=ax)
df.plot(x="DATE", y="AUD_CHF_SELL", ax=ax)
#plt.ylim(0, 1)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Draw a line chart
ax = plt.gca()


df.plot(x="DATE", y="USD_SGD_BUY", ax=ax)
df.plot(x="DATE", y="USD_SGD_SELL", ax=ax)
#plt.ylim(0, 1)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Draw a line chart
ax = plt.gca()


df.plot(x="DATE", y="EUR_CAD_BUY", ax=ax)
df.plot(x="DATE", y="EUR_CAD_SELL", ax=ax)
#plt.ylim(0, 1)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Draw a line chart
ax = plt.gca()


df.plot(x="DATE", y="GBP_CAD_BUY", ax=ax)
df.plot(x="DATE", y="GBP_CAD_SELL", ax=ax)
#plt.ylim(0, 1)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# # The End
#
# ##### Thank you
