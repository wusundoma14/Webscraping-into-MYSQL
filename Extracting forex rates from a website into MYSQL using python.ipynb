# %% [markdown]
# # Welcome to Part 1

# %% [markdown]
# ## 1. Libraries used
#
# ### I downloaded all libraries used for this project.

# %%
#install the connector library
# %pip install mysql-connector-python
#import the connector
import mysql.connector
#create the connection object and cursor object
from mysql.connector import Error


# %pip install selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup
import requests
from bs4 import BeautifulSoup


import numpy as np
import pandas as pd

import datetime
import time
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Connecting to database
#
#
# ### I connected to my database "MYSQL"

# %%
connection = mysql.connector.connect(host='***********',
                                         database='***********',
                                         user='***********',
                                     password='***********')
if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

else: 
    print("Error while connecting to MySQL", e)
# Out:
# Connected to MySQL Server version  5.5.5-10.4.25-MariaDB
# You're connected to database:  ('mydbuser',)

# %% [markdown]
# ## 3. Constructing a table in the database

# %%
#Construct the Create Table DDL statement - replace the ... with rest of the statement
createQuery = "create table IF NOT EXISTS forextrade(DATE DATETIME, AUD_CAD_BUY FLOAT(32), AUD_CAD_SELL FLOAT(32), AUD_CHF_BUY FLOAT(32), AUD_CHF_SELL FLOAT(32), AUD_HKD_BUY FLOAT(32), AUD_HKD_SELL FLOAT(32), AUD_JPY_BUY FLOAT(32), AUD_JPY_SELL FLOAT(32), AUD_NZD_BUY FLOAT(32), AUD_NZD_SELL FLOAT(32), AUD_SGD_BUY FLOAT(32), AUD_SGD_SELL FLOAT(32), AUD_USD_BUY FLOAT(32), AUD_USD_SELL FLOAT(32), CAD_CHF_BUY FLOAT(32), CAD_CHF_SELL FLOAT(32), CAD_HKD_BUY FLOAT(32), CAD_HKD_SELL FLOAT(32), CAD_JPY_BUY FLOAT(32), CAD_JPY_SELL FLOAT(32), CAD_SGD_BUY FLOAT(32), CAD_SGD_SELL FLOAT(32), CHF_HKD_BUY FLOAT(32), CHF_HKD_SELL FLOAT(32), CHF_JPY_BUY FLOAT(32), CHF_JPY_SELL FLOAT(32), CHF_ZAR_BUY FLOAT(32), CHF_ZAR_SELL FLOAT(32), EUR_AUD_BUY FLOAT(32), EUR_AUD_SELL FLOAT(32), EUR_CAD_BUY FLOAT(32), EUR_CAD_SELL FLOAT(32), EUR_CHF_BUY FLOAT(32), EUR_CHF_SELL FLOAT(32), EUR_CZK_BUY FLOAT(32), EUR_CZK_SELL FLOAT(32), EUR_DKK_BUY FLOAT(32), EUR_DKK_SELL FLOAT(32), EUR_GBP_BUY FLOAT(32), EUR_GBP_SELL FLOAT(32), EUR_HKD_BUY FLOAT(32), EUR_HKD_SELL FLOAT(32), EUR_HUF_BUY FLOAT(32), EUR_HUF_SELL FLOAT(32), EUR_JPY_BUY FLOAT(32), EUR_JPY_SELL FLOAT(32), EUR_NOK_BUY FLOAT(32), EUR_NOK_SELL FLOAT(32), EUR_NZD_BUY FLOAT(32), EUR_NZD_SELL FLOAT(32), EUR_PLN_BUY FLOAT(32), EUR_PLN_SELL FLOAT(32), EUR_SEK_BUY FLOAT(32), EUR_SEK_SELL FLOAT(32), EUR_SGD_BUY FLOAT(32), EUR_SGD_SELL FLOAT(32), EUR_TRY_BUY FLOAT(32), EUR_TRY_SELL  FLOAT(32), EUR_USD_BUY FLOAT(32), EUR_USD_SELL FLOAT(32), EUR_ZAR_BUY FLOAT(32), EUR_ZAR_SELL FLOAT(32), GBP_AUD_BUY FLOAT(32), GBP_AUD_SELL FLOAT(32), GBP_CAD_BUY FLOAT(32), GBP_CAD_SELL FLOAT(32), GBP_CHF_BUY FLOAT(32), GBP_CHF_SELL FLOAT(32), GBP_HKD_BUY FLOAT(32), GBP_HKD_SELL FLOAT(32), GBP_JPY_BUY FLOAT(32), GBP_JPY_SELL FLOAT(32), GBP_NZD_BUY FLOAT(32), GBP_NZD_SELL FLOAT(32), GBP_PLN_BUY FLOAT(32), GBP_PLN_SELL FLOAT(32), GBP_SGD_BUY FLOAT(32), GBP_SGD_SELL FLOAT(32), GBP_USD_BUY FLOAT(32), GBP_USD_SELL FLOAT(32), GBP_ZAR_BUY FLOAT(32), GBP_ZAR_SELL FLOAT(32), HKD_JPY_BUY FLOAT(32), HKD_JPY_SELL FLOAT(32), NZD_CAD_BUY FLOAT(32), NZD_CAD_SELL FLOAT(32), NZD_CHF_BUY FLOAT(32), NZD_CHF_SELL FLOAT(32), NZD_HKD_BUY FLOAT(32), NZD_HKD_SELL FLOAT(32), NZD_JPY_BUY FLOAT(32), NZD_JPY_SELL FLOAT(32), NZD_SGD_BUY FLOAT(32), NZD_SGD_SELL FLOAT(32), NZD_USD_BUY FLOAT(32), NZD_USD_SELL FLOAT(32), SGD_CHF_BUY FLOAT(32), SGD_CHF_SELL FLOAT(32), SGD_JPY_BUY FLOAT(32), SGD_JPY_SELL FLOAT(32), TRY_JPY_BUY FLOAT(32), TRY_JPY_SELL FLOAT(32), USD_CAD_BUY FLOAT(32), USD_CAD_SELL FLOAT(32), USD_CHF_BUY FLOAT(32), USD_CHF_SELL FLOAT(32), USD_CNH_BUY FLOAT(32), USD_CNH_SELL FLOAT(32), USD_CZK_BUY FLOAT(32), USD_CZK_SELL FLOAT(32), USD_DKK_BUY FLOAT(32), USD_DKK_SELL FLOAT(32), USD_HKD_BUY FLOAT(32), USD_HKD_SELL FLOAT(32), USD_HUF_BUY FLOAT(32), USD_HUF_SELL FLOAT(32), USD_JPY_BUY FLOAT(32), USD_JPY_SELL FLOAT(32), USD_MXN_BUY FLOAT(32), USD_MXN_SELL FLOAT(32), USD_NOK_BUY FLOAT(32), USD_NOK_SELL FLOAT(32), USD_PLN_BUY FLOAT(32), USD_PLN_SELL FLOAT(32), USD_SEK_BUY FLOAT(32), USD_SEK_SELL FLOAT(32), USD_SGD_BUY FLOAT(32), USD_SGD_SELL FLOAT(32), USD_THB_BUY FLOAT(32), USD_THB_SELL FLOAT(32), USD_TRY_BUY FLOAT(32), USD_TRY_SELL FLOAT(32), USD_ZAR_BUY FLOAT(32), USD_ZAR_SELL FLOAT(32), ZAR_JPY_BUY FLOAT(32), ZAR_JPY_SELL FLOAT(32))"


#Now fill in the name of the method and execute the statement
createStmt = cursor.execute(createQuery)

# %% [markdown]
# ## 4. Scraping the website and storing the data into MYSQL
#
# #### I scraped the oando trading website using both beautifulsoup4 and selenium and transfered the data into my database. This action is continous using the datetime function.

# %%
I_D = 1
while 1:
   url = "https://www.oanda.com/us-en/trading/spreads-margin/"
   options = Options()
   options.add_argument('--headless')
   options.add_argument('--disable-gpu')
   driver = webdriver.Chrome(chrome_options=options)
   driver.get(url)
   time.sleep(5)
   page = driver.page_source
   driver.quit()
   soup = BeautifulSoup(page, 'html.parser')
   containers = soup.find_all('div', attrs={
       'class':'OandaLiveRates__tdText__1qMfK OandaLiveRates__highlightWidthLimit__I88Va'})
   DATE = datetime.datetime.now()
   
   
   AUD_CAD_BUY = containers[0].get_text()
   AUD_CAD_SELL = containers[1].get_text()
   AUD_CHF_BUY = containers[2].get_text()
   AUD_CHF_SELL = containers[3].get_text()
   AUD_HKD_BUY = containers[4].get_text()
   AUD_HKD_SELL = containers[5].get_text()
   AUD_JPY_BUY = containers[6].get_text()
   AUD_JPY_SELL = containers[7].get_text()
   AUD_NZD_BUY = containers[8].get_text()
   AUD_NZD_SELL = containers[9].get_text()
   AUD_SGD_BUY = containers[10].get_text()
   AUD_SGD_SELL = containers[11].get_text()
   AUD_USD_BUY = containers[12].get_text()
   AUD_USD_SELL = containers[13].get_text()
    
   CAD_CHF_BUY = containers[14].get_text()
   CAD_CHF_SELL = containers[15].get_text()
   CAD_HKD_BUY = containers[16].get_text()
   CAD_HKD_SELL = containers[17].get_text()
   CAD_JPY_BUY = containers[18].get_text()
   CAD_JPY_SELL = containers[19].get_text()
   CAD_SGD_BUY = containers[20].get_text()
   CAD_SGD_SELL = containers[21].get_text()
    
   CHF_HKD_BUY = containers[22].get_text()
   CHF_HKD_SELL = containers[23].get_text()
   CHF_JPY_BUY = containers[24].get_text()
   CHF_JPY_SELL = containers[25].get_text()
   CHF_ZAR_BUY = containers[26].get_text()
   CHF_ZAR_SELL = containers[27].get_text()
    
   EUR_AUD_BUY = containers[28].get_text()
   EUR_AUD_SELL = containers[29].get_text()
   EUR_CAD_BUY = containers[30].get_text()
   EUR_CAD_SELL = containers[31].get_text()
   EUR_CHF_BUY = containers[32].get_text()
   EUR_CHF_SELL = containers[33].get_text()
   EUR_CZK_BUY = containers[34].get_text()
   EUR_CZK_SELL = containers[35].get_text()
   EUR_DKK_BUY = containers[36].get_text()
   EUR_DKK_SELL = containers[37].get_text()
   EUR_GBP_BUY = containers[38].get_text()
   EUR_GBP_SELL = containers[39].get_text()
   EUR_HKD_BUY = containers[40].get_text()
   EUR_HKD_SELL = containers[41].get_text()
   EUR_HUF_BUY = containers[42].get_text()
   EUR_HUF_SELL = containers[43].get_text()
   EUR_JPY_BUY = containers[44].get_text()
   EUR_JPY_SELL = containers[45].get_text()
   EUR_NOK_BUY = containers[46].get_text()
   EUR_NOK_SELL = containers[47].get_text()
   EUR_NZD_BUY = containers[48].get_text()
   EUR_NZD_SELL = containers[49].get_text()
   EUR_PLN_BUY = containers[50].get_text()
   EUR_PLN_SELL = containers[51].get_text()
   EUR_SEK_BUY = containers[52].get_text()
   EUR_SEK_SELL = containers[53].get_text()
   EUR_SGD_BUY = containers[54].get_text()
   EUR_SGD_SELL = containers[55].get_text()
   EUR_TRY_BUY = containers[56].get_text()
   EUR_TRY_SELL =containers[57].get_text() 
   EUR_USD_BUY =  containers[58].get_text()
   EUR_USD_SELL =containers[59].get_text()
   EUR_ZAR_BUY =  containers[60].get_text()
   EUR_ZAR_SELL =containers[61].get_text()
    
   GBP_AUD_BUY =  containers[62].get_text()
   GBP_AUD_SELL =containers[63].get_text()
   GBP_CAD_BUY =  containers[64].get_text()
   GBP_CAD_SELL =containers[65].get_text()
   GBP_CHF_BUY =  containers[66].get_text()
   GBP_CHF_SELL =containers[67].get_text()
   GBP_HKD_BUY =  containers[68].get_text()
   GBP_HKD_SELL =containers[69].get_text()
   GBP_JPY_BUY =  containers[70].get_text()
   GBP_JPY_SELL =containers[71].get_text()
   GBP_NZD_BUY =  containers[72].get_text()
   GBP_NZD_SELL =containers[73].get_text()
   GBP_PLN_BUY =  containers[74].get_text()
   GBP_PLN_SELL =containers[75].get_text()
   GBP_SGD_BUY =  containers[76].get_text()
   GBP_SGD_SELL =containers[77].get_text()
   GBP_USD_BUY =  containers[78].get_text()
   GBP_USD_SELL =containers[79].get_text()
   GBP_ZAR_BUY =  containers[80].get_text()
   GBP_ZAR_SELL =containers[81].get_text()
    
   HKD_JPY_BUY =  containers[82].get_text()
   HKD_JPY_SELL =containers[83].get_text()
    
   NZD_CAD_BUY =  containers[84].get_text()
   NZD_CAD_SELL =containers[85].get_text()
   NZD_CHF_BUY =  containers[86].get_text()
   NZD_CHF_SELL =containers[87].get_text()
   NZD_HKD_BUY =  containers[88].get_text()
   NZD_HKD_SELL =containers[89].get_text()
   NZD_JPY_BUY =  containers[90].get_text()
   NZD_JPY_SELL =containers[91].get_text()
   NZD_SGD_BUY =  containers[92].get_text()
   NZD_SGD_SELL =containers[93].get_text()
   NZD_USD_BUY =  containers[94].get_text()
   NZD_USD_SELL =containers[95].get_text()
    
   SGD_CHF_BUY =  containers[96].get_text()
   SGD_CHF_SELL =containers[97].get_text()
   SGD_JPY_BUY =  containers[98].get_text()
   SGD_JPY_SELL =containers[99].get_text()
    
   TRY_JPY_BUY =  containers[100].get_text()
   TRY_JPY_SELL =containers[101].get_text()
    
   USD_CAD_BUY =  containers[102].get_text()
   USD_CAD_SELL =containers[103].get_text()
   USD_CHF_BUY =  containers[104].get_text()
   USD_CHF_SELL =containers[105].get_text()
   USD_CNH_BUY =  containers[106].get_text()
   USD_CNH_SELL =containers[107].get_text()
   USD_CZK_BUY =  containers[108].get_text()
   USD_CZK_SELL =containers[109].get_text()
   USD_DKK_BUY =  containers[110].get_text()
   USD_DKK_SELL =containers[111].get_text()
   USD_HKD_BUY =  containers[112].get_text()
   USD_HKD_SELL =containers[113].get_text()
   USD_HUF_BUY =  containers[114].get_text()
   USD_HUF_SELL =containers[115].get_text()
   USD_JPY_BUY =  containers[116].get_text()
   USD_JPY_SELL =containers[117].get_text()
   USD_MXN_BUY =  containers[118].get_text()
   USD_MXN_SELL =containers[119].get_text()
   USD_NOK_BUY =  containers[120].get_text()
   USD_NOK_SELL =containers[121].get_text()
   USD_PLN_BUY =  containers[122].get_text()
   USD_PLN_SELL =containers[123].get_text()
   USD_SEK_BUY =  containers[124].get_text()
   USD_SEK_SELL =containers[125].get_text()
   USD_SGD_BUY =  containers[126].get_text()
   USD_SGD_SELL =containers[127].get_text()
   USD_THB_BUY =  containers[128].get_text()
   USD_THB_SELL =containers[129].get_text()
   USD_TRY_BUY =  containers[130].get_text()
   USD_TRY_SELL =containers[131].get_text()
   USD_ZAR_BUY =  containers[132].get_text()
   USD_ZAR_SELL =containers[133].get_text()
    
   ZAR_JPY_BUY =  containers[134].get_text()
   ZAR_JPY_SELL = containers[135].get_text()
   
   
   print(
   "\nDATE=", DATE,    
   "\nAUD_CAD_BUY = ",AUD_CAD_BUY ,
   "\nAUD_CAD_SELL =",AUD_CAD_SELL,
   "\nAUD_CHF_BUY = ",AUD_CHF_BUY ,
   "\nAUD_CHF_SELL =",AUD_CHF_SELL,
   "\nAUD_HKD_BUY = ",AUD_HKD_BUY ,
   "\nAUD_HKD_SELL =",AUD_HKD_SELL,
   "\nAUD_JPY_BUY = ",AUD_JPY_BUY ,
   "\nAUD_JPY_SELL =",AUD_JPY_SELL,
   "\nAUD_NZD_BUY = ",AUD_NZD_BUY ,
   "\nAUD_NZD_SELL =",AUD_NZD_SELL,
   "\nAUD_SGD_BUY = ",AUD_SGD_BUY ,
   "\nAUD_SGD_SELL =",AUD_SGD_SELL,
   "\nAUD_USD_BUY = ",AUD_USD_BUY ,
   "\nAUD_USD_SELL =",AUD_USD_SELL,
   "\nCAD_CHF_BUY = ",CAD_CHF_BUY ,
   "\nCAD_CHF_SELL =",CAD_CHF_SELL,
   "\nCAD_HKD_BUY = ",CAD_HKD_BUY ,
   "\nCAD_HKD_SELL =",CAD_HKD_SELL,
   "\nCAD_JPY_BUY = ",CAD_JPY_BUY ,
   "\nCAD_JPY_SELL =",CAD_JPY_SELL,
   "\nCAD_SGD_BUY = ",CAD_SGD_BUY ,
   "\nCAD_SGD_SELL =",CAD_SGD_SELL,
   "\nCHF_HKD_BUY = ",CHF_HKD_BUY ,
   "\nCHF_HKD_SELL =",CHF_HKD_SELL,
   "\nCHF_JPY_BUY = ",CHF_JPY_BUY ,
   "\nCHF_JPY_SELL =",CHF_JPY_SELL,
   "\nCHF_ZAR_BUY = ",CHF_ZAR_BUY ,
   "\nCHF_ZAR_SELL =",CHF_ZAR_SELL,
   "\nEUR_AUD_BUY = ",EUR_AUD_BUY ,
   "\nEUR_AUD_SELL =",EUR_AUD_SELL,
   "\nEUR_CAD_BUY = ",EUR_CAD_BUY ,
   "\nEUR_CAD_SELL =",EUR_CAD_SELL,
   "\nEUR_CHF_BUY = ",EUR_CHF_BUY ,
   "\nEUR_CHF_SELL =",EUR_CHF_SELL,
   "\nEUR_CZK_BUY = ",EUR_CZK_BUY ,
   "\nEUR_CZK_SELL =",EUR_CZK_SELL,
   "\nEUR_DKK_BUY = ",EUR_DKK_BUY ,
   "\nEUR_DKK_SELL =",EUR_DKK_SELL,
   "\nEUR_GBP_BUY = ",EUR_GBP_BUY ,
   "\nEUR_GBP_SELL =",EUR_GBP_SELL,
   "\nEUR_HKD_BUY = ",EUR_HKD_BUY ,
   "\nEUR_HKD_SELL =",EUR_HKD_SELL,
   "\nEUR_HUF_BUY = ",EUR_HUF_BUY ,
   "\nEUR_HUF_SELL =",EUR_HUF_SELL,
   "\nEUR_JPY_BUY = ",EUR_JPY_BUY ,
   "\nEUR_JPY_SELL =",EUR_JPY_SELL,
   "\nEUR_NOK_BUY = ",EUR_NOK_BUY ,
   "\nEUR_NOK_SELL =",EUR_NOK_SELL,
   "\nEUR_NZD_BUY = ",EUR_NZD_BUY ,
   "\nEUR_NZD_SELL =",EUR_NZD_SELL,
   "\nEUR_PLN_BUY = ",EUR_PLN_BUY ,
   "\nEUR_PLN_SELL =",EUR_PLN_SELL,
   "\nEUR_SEK_BUY = ",EUR_SEK_BUY ,
   "\nEUR_SEK_SELL =",EUR_SEK_SELL,
   "\nEUR_SGD_BUY = ",EUR_SGD_BUY ,
   "\nEUR_SGD_SELL =",EUR_SGD_SELL,
   "\nEUR_TRY_BUY = ",EUR_TRY_BUY ,
   "\nEUR_TRY_SELL =",EUR_TRY_SELL,
   "\nEUR_USD_BUY = ",EUR_USD_BUY ,
   "\nEUR_USD_SELL =",EUR_USD_SELL,
   "\nEUR_ZAR_BUY = ",EUR_ZAR_BUY ,
   "\nEUR_ZAR_SELL =",EUR_ZAR_SELL,
   "\nGBP_AUD_BUY = ",GBP_AUD_BUY ,
   "\nGBP_AUD_SELL =",GBP_AUD_SELL,
   "\nGBP_CAD_BUY = ",GBP_CAD_BUY ,
   "\nGBP_CAD_SELL =",GBP_CAD_SELL,
   "\nGBP_CHF_BUY = ",GBP_CHF_BUY ,
   "\nGBP_CHF_SELL =",GBP_CHF_SELL,
   "\nGBP_HKD_BUY = ",GBP_HKD_BUY ,
   "\nGBP_HKD_SELL =",GBP_HKD_SELL,
   "\nGBP_JPY_BUY = ",GBP_JPY_BUY ,
   "\nGBP_JPY_SELL =",GBP_JPY_SELL,
   "\nGBP_NZD_BUY = ",GBP_NZD_BUY ,
   "\nGBP_NZD_SELL =",GBP_NZD_SELL,
   "\nGBP_PLN_BUY = ",GBP_PLN_BUY ,
   "\nGBP_PLN_SELL =",GBP_PLN_SELL,
   "\nGBP_SGD_BUY = ",GBP_SGD_BUY ,
   "\nGBP_SGD_SELL =",GBP_SGD_SELL,
   "\nGBP_USD_BUY = ",GBP_USD_BUY ,
   "\nGBP_USD_SELL =",GBP_USD_SELL,
   "\nGBP_ZAR_BUY = ",GBP_ZAR_BUY ,
   "\nGBP_ZAR_SELL =",GBP_ZAR_SELL,
   "\nHKD_JPY_BUY = ",HKD_JPY_BUY ,
   "\nHKD_JPY_SELL =",HKD_JPY_SELL,
   "\nNZD_CAD_BUY = ",NZD_CAD_BUY ,
   "\nNZD_CAD_SELL =",NZD_CAD_SELL,
   "\nNZD_CHF_BUY = ",NZD_CHF_BUY ,
   "\nNZD_CHF_SELL =",NZD_CHF_SELL,
   "\nNZD_HKD_BUY = ",NZD_HKD_BUY ,
   "\nNZD_HKD_SELL =",NZD_HKD_SELL,
   "\nNZD_JPY_BUY = ",NZD_JPY_BUY ,
   "\nNZD_JPY_SELL =",NZD_JPY_SELL,
   "\nNZD_SGD_BUY = ",NZD_SGD_BUY ,
   "\nNZD_SGD_SELL =",NZD_SGD_SELL,
   "\nNZD_USD_BUY = ",NZD_USD_BUY ,
   "\nNZD_USD_SELL =",NZD_USD_SELL,
   "\nSGD_CHF_BUY = ",SGD_CHF_BUY ,
   "\nSGD_CHF_SELL =",SGD_CHF_SELL,
   "\nSGD_JPY_BUY = ",SGD_JPY_BUY ,
   "\nSGD_JPY_SELL =",SGD_JPY_SELL,
   "\nTRY_JPY_BUY = ",TRY_JPY_BUY ,
   "\nTRY_JPY_SELL =",TRY_JPY_SELL,
   "\nUSD_CAD_BUY = ",USD_CAD_BUY ,
   "\nUSD_CAD_SELL =",USD_CAD_SELL,
   "\nUSD_CHF_BUY = ",USD_CHF_BUY ,
   "\nUSD_CHF_SELL =",USD_CHF_SELL,
   "\nUSD_CNH_BUY = ",USD_CNH_BUY ,
   "\nUSD_CNH_SELL =",USD_CNH_SELL,
   "\nUSD_CZK_BUY = ",USD_CZK_BUY ,
   "\nUSD_CZK_SELL =",USD_CZK_SELL,
   "\nUSD_DKK_BUY = ",USD_DKK_BUY ,
   "\nUSD_DKK_SELL =",USD_DKK_SELL,
   "\nUSD_HKD_BUY = ",USD_HKD_BUY ,
   "\nUSD_HKD_SELL =",USD_HKD_SELL,
   "\nUSD_HUF_BUY = ",USD_HUF_BUY ,
   "\nUSD_HUF_SELL =",USD_HUF_SELL,
   "\nUSD_JPY_BUY = ",USD_JPY_BUY ,
   "\nUSD_JPY_SELL =",USD_JPY_SELL,
   "\nUSD_MXN_BUY = ",USD_MXN_BUY ,
   "\nUSD_MXN_SELL =",USD_MXN_SELL,
   "\nUSD_NOK_BUY = ",USD_NOK_BUY ,
   "\nUSD_NOK_SELL =",USD_NOK_SELL,
   "\nUSD_PLN_BUY = ",USD_PLN_BUY ,
   "\nUSD_PLN_SELL =",USD_PLN_SELL,
   "\nUSD_SEK_BUY = ",USD_SEK_BUY ,
   "\nUSD_SEK_SELL =",USD_SEK_SELL,
   "\nUSD_SGD_BUY = ",USD_SGD_BUY ,
   "\nUSD_SGD_SELL =",USD_SGD_SELL,
   "\nUSD_THB_BUY = ",USD_THB_BUY ,
   "\nUSD_THB_SELL =",USD_THB_SELL,
   "\nUSD_TRY_BUY = ",USD_TRY_BUY ,
   "\nUSD_TRY_SELL =",USD_TRY_SELL,
   "\nUSD_ZAR_BUY = ",USD_ZAR_BUY ,
   "\nUSD_ZAR_SELL =",USD_ZAR_SELL,
   "\nZAR_JPY_BUY = ",ZAR_JPY_BUY ,
   "\nZAR_JPY_SELL =",ZAR_JPY_SELL 
   )

   
   ## 5. Storing the scraped data into MYSQL
   Val = (DATE, AUD_CAD_BUY, AUD_CAD_SELL, AUD_CHF_BUY, AUD_CHF_SELL, AUD_HKD_BUY, AUD_HKD_SELL, AUD_JPY_BUY, AUD_JPY_SELL, AUD_NZD_BUY, AUD_NZD_SELL, AUD_SGD_BUY, AUD_SGD_SELL, AUD_USD_BUY, AUD_USD_SELL, CAD_CHF_BUY, CAD_CHF_SELL, CAD_HKD_BUY, CAD_HKD_SELL, CAD_JPY_BUY, CAD_JPY_SELL, CAD_SGD_BUY, CAD_SGD_SELL, CHF_HKD_BUY, CHF_HKD_SELL, CHF_JPY_BUY, CHF_JPY_SELL, CHF_ZAR_BUY, CHF_ZAR_SELL, EUR_AUD_BUY, EUR_AUD_SELL, EUR_CAD_BUY, EUR_CAD_SELL, EUR_CHF_BUY, EUR_CHF_SELL, EUR_CZK_BUY, EUR_CZK_SELL, EUR_DKK_BUY, EUR_DKK_SELL, EUR_GBP_BUY, EUR_GBP_SELL, EUR_HKD_BUY, EUR_HKD_SELL, EUR_HUF_BUY, EUR_HUF_SELL, EUR_JPY_BUY, EUR_JPY_SELL, EUR_NOK_BUY, EUR_NOK_SELL, EUR_NZD_BUY, EUR_NZD_SELL, EUR_PLN_BUY, EUR_PLN_SELL, EUR_SEK_BUY, EUR_SEK_SELL, EUR_SGD_BUY, EUR_SGD_SELL, EUR_TRY_BUY, EUR_TRY_SELL, EUR_USD_BUY, EUR_USD_SELL, EUR_ZAR_BUY, EUR_ZAR_SELL, GBP_AUD_BUY, GBP_AUD_SELL, GBP_CAD_BUY, GBP_CAD_SELL, GBP_CHF_BUY, GBP_CHF_SELL, GBP_HKD_BUY, GBP_HKD_SELL, GBP_JPY_BUY, GBP_JPY_SELL, GBP_NZD_BUY, GBP_NZD_SELL, GBP_PLN_BUY, GBP_PLN_SELL, GBP_SGD_BUY, GBP_SGD_SELL, GBP_USD_BUY, GBP_USD_SELL, GBP_ZAR_BUY, GBP_ZAR_SELL, HKD_JPY_BUY, HKD_JPY_SELL, NZD_CAD_BUY, NZD_CAD_SELL, NZD_CHF_BUY, NZD_CHF_SELL, NZD_HKD_BUY, NZD_HKD_SELL, NZD_JPY_BUY, NZD_JPY_SELL, NZD_SGD_BUY, NZD_SGD_SELL, NZD_USD_BUY, NZD_USD_SELL, SGD_CHF_BUY, SGD_CHF_SELL, SGD_JPY_BUY, SGD_JPY_SELL, TRY_JPY_BUY, TRY_JPY_SELL, USD_CAD_BUY, USD_CAD_SELL, USD_CHF_BUY, USD_CHF_SELL, USD_CNH_BUY, USD_CNH_SELL, USD_CZK_BUY, USD_CZK_SELL, USD_DKK_BUY, USD_DKK_SELL, USD_HKD_BUY, USD_HKD_SELL, USD_HUF_BUY, USD_HUF_SELL, USD_JPY_BUY, USD_JPY_SELL, USD_MXN_BUY, USD_MXN_SELL, USD_NOK_BUY, USD_NOK_SELL, USD_PLN_BUY, USD_PLN_SELL, USD_SEK_BUY, USD_SEK_SELL, USD_SGD_BUY, USD_SGD_SELL, USD_THB_BUY, USD_THB_SELL, USD_TRY_BUY, USD_TRY_SELL, USD_ZAR_BUY, USD_ZAR_SELL, ZAR_JPY_BUY, ZAR_JPY_SELL)
   
   
   insertQuery = 'INSERT INTO forextrade(DATE, AUD_CAD_BUY, AUD_CAD_SELL, AUD_CHF_BUY, AUD_CHF_SELL, AUD_HKD_BUY, AUD_HKD_SELL, AUD_JPY_BUY, AUD_JPY_SELL, AUD_NZD_BUY, AUD_NZD_SELL, AUD_SGD_BUY, AUD_SGD_SELL, AUD_USD_BUY, AUD_USD_SELL, CAD_CHF_BUY, CAD_CHF_SELL, CAD_HKD_BUY, CAD_HKD_SELL, CAD_JPY_BUY, CAD_JPY_SELL, CAD_SGD_BUY, CAD_SGD_SELL, CHF_HKD_BUY, CHF_HKD_SELL, CHF_JPY_BUY, CHF_JPY_SELL, CHF_ZAR_BUY, CHF_ZAR_SELL, EUR_AUD_BUY, EUR_AUD_SELL, EUR_CAD_BUY, EUR_CAD_SELL, EUR_CHF_BUY, EUR_CHF_SELL, EUR_CZK_BUY, EUR_CZK_SELL, EUR_DKK_BUY, EUR_DKK_SELL, EUR_GBP_BUY, EUR_GBP_SELL, EUR_HKD_BUY, EUR_HKD_SELL, EUR_HUF_BUY, EUR_HUF_SELL, EUR_JPY_BUY, EUR_JPY_SELL, EUR_NOK_BUY, EUR_NOK_SELL, EUR_NZD_BUY, EUR_NZD_SELL, EUR_PLN_BUY, EUR_PLN_SELL, EUR_SEK_BUY, EUR_SEK_SELL, EUR_SGD_BUY, EUR_SGD_SELL, EUR_TRY_BUY, EUR_TRY_SELL, EUR_USD_BUY, EUR_USD_SELL, EUR_ZAR_BUY, EUR_ZAR_SELL, GBP_AUD_BUY, GBP_AUD_SELL, GBP_CAD_BUY, GBP_CAD_SELL, GBP_CHF_BUY, GBP_CHF_SELL, GBP_HKD_BUY, GBP_HKD_SELL, GBP_JPY_BUY, GBP_JPY_SELL, GBP_NZD_BUY, GBP_NZD_SELL, GBP_PLN_BUY, GBP_PLN_SELL, GBP_SGD_BUY, GBP_SGD_SELL, GBP_USD_BUY, GBP_USD_SELL, GBP_ZAR_BUY, GBP_ZAR_SELL, HKD_JPY_BUY, HKD_JPY_SELL, NZD_CAD_BUY, NZD_CAD_SELL, NZD_CHF_BUY, NZD_CHF_SELL, NZD_HKD_BUY, NZD_HKD_SELL, NZD_JPY_BUY, NZD_JPY_SELL, NZD_SGD_BUY, NZD_SGD_SELL, NZD_USD_BUY, NZD_USD_SELL, SGD_CHF_BUY, SGD_CHF_SELL, SGD_JPY_BUY, SGD_JPY_SELL, TRY_JPY_BUY, TRY_JPY_SELL, USD_CAD_BUY, USD_CAD_SELL, USD_CHF_BUY, USD_CHF_SELL, USD_CNH_BUY, USD_CNH_SELL, USD_CZK_BUY, USD_CZK_SELL, USD_DKK_BUY, USD_DKK_SELL, USD_HKD_BUY, USD_HKD_SELL, USD_HUF_BUY, USD_HUF_SELL, USD_JPY_BUY, USD_JPY_SELL, USD_MXN_BUY, USD_MXN_SELL, USD_NOK_BUY, USD_NOK_SELL, USD_PLN_BUY, USD_PLN_SELL, USD_SEK_BUY, USD_SEK_SELL, USD_SGD_BUY, USD_SGD_SELL, USD_THB_BUY, USD_THB_SELL, USD_TRY_BUY, USD_TRY_SELL, USD_ZAR_BUY, USD_ZAR_SELL, ZAR_JPY_BUY, ZAR_JPY_SELL) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'
   
   
   insertstmt = cursor.execute(insertQuery, Val)
   
   # Commit the changes to the database
   connection.commit()

   continue
   time.sleep(120)
I_D += 1
#time.sleep(120)
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_4180\1155488914.py:7: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options)
# DATE= 2023-01-13 02:54:47.407848
# AUD_CAD_BUY =  0.93126
# AUD_CAD_SELL = 0.93153
# AUD_CHF_BUY =  0.64639
# AUD_CHF_SELL = 0.64656
# AUD_HKD_BUY =  5.43706
# AUD_HKD_SELL = 5.43777
# AUD_JPY_BUY =  89.875
# AUD_JPY_SELL = 89.9
# AUD_NZD_BUY =  1.09051
# AUD_NZD_SELL = 1.09085
# AUD_SGD_BUY =  0.92063
# AUD_SGD_SELL = 0.92104
# AUD_USD_BUY =  0.6961
# AUD_USD_SELL = 0.69623
# CAD_CHF_BUY =  0.69397
# CAD_CHF_SELL = 0.69419
# CAD_HKD_BUY =  5.83747
# CAD_HKD_SELL = 5.8382
# CAD_JPY_BUY =  96.484
# CAD_JPY_SELL = 96.523
# CAD_SGD_BUY =  0.98855
# CAD_SGD_SELL = 0.98872
# CHF_HKD_BUY =  8.41025
# CHF_HKD_SELL = 8.41165
# CHF_JPY_BUY =  139.027
# CHF_JPY_SELL = 139.057
# CHF_ZAR_BUY =  18.01498
# CHF_ZAR_SELL = 18.04012
# EUR_AUD_BUY =  1.55793
# EUR_AUD_SELL = 1.55836
# EUR_CAD_BUY =  1.45111
# ...

# %% [markdown]
# # Thank you.
#
# #### See the part 2 for data analysis on the project
